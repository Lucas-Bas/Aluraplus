# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas-Bas/Aluraplus/blob/main/Desafios_Py_etc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

n = 0
while n < 5:
    lista_de_medias[n] = lista_de_medias[n] + 1.0
    if lista_de_medias[n] > 10.0:
        lista_de_medias[n] = 10.0
    n = n + 1

print(lista_de_medias)
# Out:
# [9.9, 8.5, 5.2, 2.4, 10.0]

# %% [markdown]
# Particionando listas

# %%
lista_de_nomes = ["Maria Silva", "João Santos", "Ana Oliveira", "Pedro Costa", "Juliana Pereira"]
lista_de_nomes[1:3]
lista_de_nomes[1:4]
# Out:
# ['João Santos', 'Ana Oliveira', 'Pedro Costa']

# %%
lista_de_nomes[1:]
lista_de_nomes[:4]
# Out:
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa']

# %% [markdown]
# Adicionando elementos a listas

# %%
lista_de_nomes.append("Fábio Carraro")
print(lista_de_nomes)
len(lista_de_nomes)
# Out:
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira', 'Fábio Carraro']
# 6

# %%
lista_de_nomes.extend(["Joana da Silva", "Paulo Silveira"])
print(lista_de_nomes)
# Out:
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira', 'Fábio Carraro', 'Joana da Silva', 'Paulo Silveira']

# %%
lista_de_nomes.append(["Márcio Costa", "Natália Pedreira"])
print(lista_de_nomes)
# Out:
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira', 'Fábio Carraro', 'Joana da Silva', 'Paulo Silveira', ['Márcio Costa', 'Natália Pedreira']]

# %%
lista_de_nomes[8]
lista_de_nomes[8][0]
# Out:
# 'Márcio Costa'

# %%
lista_de_nomes.remove("Paulo Silveira")
print(lista_de_nomes)
lista_de_nomes.pop()
print(lista_de_nomes)
lista_de_nomes.pop(2)
print(lista_de_nomes)
# Out:
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira', 'Fábio Carraro', 'Joana da Silva', ['Márcio Costa', 'Natália Pedreira']]
# ['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa', 'Juliana Pereira', 'Fábio Carraro', 'Joana da Silva']
# ['Maria Silva', 'João Santos', 'Pedro Costa', 'Juliana Pereira', 'Fábio Carraro', 'Joana da Silva']

# %% [markdown]
# Introduzindo a estrutura de dados dicionário

# %%
lista_de_nomes = ["Maria Silva", "João Santos", "Ana Oliveira", "Pedro Costa", "Juliana Pereira"]
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
dict_de_nomes_e_media = {}

# %%
dict_de_nomes_e_media = {
    "Maria Silva": 8.9,
    "João Santos": 7.5,
    "Ana Oliveira": 4.2,
    "Pedro Costa": 1.4,
    "Juliana Pereira": 9.5
}

# %%
dict_de_nomes_e_media["Maria Silva"]
# Out:
# 8.9

# %%
dict_de_nomes_e_media.get("Maria Silva")
# Out:
# 8.9

# %%
dict_de_nomes_e_media.pop("Juliana Pereira")
# Out:
# 9.5

# %%
dict_de_nomes_e_media.items()
# Out:
# dict_items([('Maria Silva', 8.9), ('João Santos', 7.5), ('Ana Oliveira', 4.2), ('Pedro Costa', 1.4)])

# %%
dict_de_nomes_e_media.keys()
# Out:
# dict_keys(['Maria Silva', 'João Santos', 'Ana Oliveira', 'Pedro Costa'])

# %%
dict_de_nomes_e_media.values()
# Out:
# dict_values([8.9, 7.5, 4.2, 1.4])

# %% [markdown]
# Desafio unir dicionários

# %%
dict_desafio = {}

# %%
dict_desafio = [

    {"nome": "Maria Silva", "média": 8.9}

]

# %%
dict_desafio = [

    {"nome": "Maria Silva", "média": 8.9},

    {"nome": "João Santos", "média": 7.5},

    {"nome": "Ana Oliveira", "média": 4.2},

    {"nome": "Pedro Costa", "média": 1.4}

]

# %%
dict_desafio[1]
# Out:
# {'nome': 'João Santos', 'média': 7.5}

# %%
dict_desafio[0]["média"]
# Out:
# 8.9

# %%
dict_desafio = [

    {"nome": "Maria Silva", "média": 8.9},

    {"nome": "João Santos", "média": 7.5},

    {"nome": "Ana Oliveira", "média": 4.2},

    {"nome": "Pedro Costa", "média": 1.4}

]

# %%
n = 0
while n < len(dict_desafio):
    print(dict_desafio[n])
    n += 1
# Out:
# {'nome': 'Maria Silva', 'média': 8.9}
# {'nome': 'João Santos', 'média': 7.5}
# {'nome': 'Ana Oliveira', 'média': 4.2}
# {'nome': 'Pedro Costa', 'média': 1.4}

# %%
for elemento in dict_desafio:
    print(elemento)
# Out:
# {'nome': 'Maria Silva', 'média': 8.9}
# {'nome': 'João Santos', 'média': 7.5}
# {'nome': 'Ana Oliveira', 'média': 4.2}
# {'nome': 'Pedro Costa', 'média': 1.4}

# %%
for n in range(5):
    print(n)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Se não especificarmos um valor inicial, o range começa do 0 até o número especificado, não incluindo o último número. Por exemplo, range(5) gera os números de 0 a 4. Podemos também especificar um valor inicial diferente de 0, como range(2, 7), que gera os números de 2 a 6. Além disso, podemos definir um passo, como range(2, 7, 2), que gera os números 2, 4 e 6, pulando de 2 em 2.

# %%
for n in range(2, 7, 2):
    print(n)
# Out:
# 2
# 4
# 6

# %% [markdown]
# Trabalhando com dicionários

# %%
pessoa = {
    "nome": "Fabricio",
    "idade": 19,
    "altura": 1.87
}

# %%
for chave, valor in pessoa.items():
    print(f"A chave é {chave} e o valor é {valor}.")
# Out:
# A chave é nome e o valor é Fabricio.
# A chave é idade e o valor é 19.
# A chave é altura e o valor é 1.87.

# %%
for n in range(11):
    if n % 2 == 0:
        print(n)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# strip(): Remove os espaços em branco do início e do final do texto.
# upper(): Converte todas as letras do texto para maiúsculas.
# split(): Divide o texto em uma lista de palavras, usando os espaços como separadores. Isso é útil para remover múltiplos espaços entre as palavras.
# ' '.join(): Junta as palavras da lista novamente em uma única string, colocando um único espaço entre cada palavra.
